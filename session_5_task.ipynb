# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmadBinAbdulJabbar/campusx/blob/main/session_5_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tuple

# %% [markdown]
# ###`Q1:` Join Tuples if similar initial element
# While working with Python tuples, we can have a problem in which we need to perform concatenation of records from the similarity of initial element. This problem can have applications in data domains such as Data Science.
#
# For eg.
# ```
# Input  : test_list = [(5, 6), (5, 7), (5, 8), (6, 10), (7, 13)]
# Output : [(5, 6, 7, 8), (6, 10), (7, 13)]
# ```

# %%
# write your code here
test_list = [(5, 6), (5, 7), (5, 8), (6, 10), (7, 13)]
output = []
processed_indices = []
for i in range(len(test_list)):
    current_tuple = test_list[i]
    for j in range(i+1,len(test_list)):
      if j in processed_indices:
        break
      if test_list[i][0] == test_list[j][0]:
        processed_indices.append(j)
        current_tuple = current_tuple + (test_list[j][1],)
    if i not in processed_indices:
      output.append(tuple(current_tuple))
print(output)
# Out:
# [(5, 6, 7, 8), (6, 10), (7, 13)]

# %% [markdown]
# ###`Q2:` Multiply Adjacent elements (both side) and take sum of right and lest side multiplication result.
#
#
# For eg.
# ```
# The original tuple : (1, 5, 7, 8, 10)
# Resultant tuple after multiplication :
#
# (1*5, 1*5+5*7, 7*5 + 7*8, 8*7 + 8*10, 10*8) -> (5, 40, 91, 136, 80)
#
# output-(5, 40, 91, 136, 80)
# ```

# %%
# write your code here

# %% [markdown]
# ###`Q3`: Check is tuples are same or not?
# Two tuples would be same if both tuples have same element at same index
# ```
# t1 = (1,2,3,0)
# t2 = (0,1,2,3)
#
# t1 and t2 are not same
# ```

# %%
# write your code here
t1 = (1,2,3,0)
t2 = (0,1,2,3)

for i in range(len(t1)):
  if t1[i] != t2[i]:
    print("t1 and t2 are not same")
    break
else:
  print("t1 and t2 are same")


if t1 == t2:
  print("t1 and t2 are same")
else:
  print("t1 and t2 are not same")
# Out:
# t1 and t2 are not same
# t1 and t2 are not same

# %% [markdown]
# ###`Q4`: Count no of tuples, list and set from a list
# ```
# list1 = [{'hi', 'bye'},{'Geeks', 'forGeeks'},('a', 'b'),['hi', 'bye'],['a', 'b']]
#
# ```
# `Output:`
#
# ```
# List-2
# Set-2
# Tuples-1
# ```

# %%
# write your code here
list1 = [{'hi', 'bye'},{'Geeks', 'forGeeks'},('a', 'b'),['hi', 'bye'],['a', 'b']]
lists = 0
sets = 0
tuples = 0
for i in range(len(list1)):
  if type(list1[i]) == list:
    lists += 1
  elif type(list1[i]) == set:
    sets += 1
  elif type(list1[i]) == tuple:
    tuples += 1
print("List-",lists)
print("Set-",sets)
print("Tuples-",tuples)

# %% [markdown]
# ###`Q5`: Shortlist Students for a Job role
# Ask user to input students record and store in tuples for each record. Then Ask user to input three things he wants in the candidate- Primary Skill, Higher Education, Year of Graduation.
#
# Show every students record in form of tuples if matches all required criteria.
#
# It is assumed that there will be only one primry skill.
#
# If no such candidate found, print `No such candidate`
#
# `Input:`
# ```
# Enter No of records- 2
# Enter Details of student-1
# Enter Student name- Manohar
# Enter Higher Education- B.Tech
# Enter Primary Skill- Python
# Enter Year of Graduation- 2022
# Enter Details of student-2
# Enter Student name- Ponian
# Enter Higher Education- B.Sc.
# Enter Primary Skill- C++
# Enter Year of Graduation- 2020
#
# Enter Job Role Requirement
# Enter Skill- Python
# Enter Higher Education- B.Tech
# Enter Year of Graduation- 2022
# ```
#
# `Output`
# ```
# ('Manohar', 'B.tech', 'Python', '2022')
# ```

# %%
# write your code here
students = []
no_of_records = int(input("Enter No of records- "))
for i in range(no_of_records):
  print(f"Enter Details of student-{i+1}")
  name = input("Enter Student name- ")
  higher_education = input("Enter Higher Education- ")
  primary_skill = input("Enter Primary Skill- ")
  year_of_graduation = input("Enter Year of Graduation- ")
  students.append((name,higher_education,primary_skill,year_of_graduation))

skill = input("\n\nEnter Job Role Requirement\nEnter Skill- ")
higher_education = input("Enter Higher Education- ")
year_of_graduation = input("Enter Year of Graduation- ")


matched = []
for i in range(len(students)):
  if students[i][2] == skill and students[i][1] == higher_education and students[i][3] == year_of_graduation:
    matched.append(students[i])

for i in range(len(matched)):
  print(matched[i])
# Out:
# Enter No of records- 2
# Enter Details of student-1
# Enter Student name- ahmad
# Enter Higher Education- BSCS
# Enter Primary Skill- python
# Enter Year of Graduation- 2024
# Enter Details of student-2
# Enter Student name- ali
# Enter Higher Education- BSSE
# Enter Primary Skill- js
# Enter Year of Graduation- 2023
# Enter Job Role Requirement
# Enter Job Role Requirement
# Enter Skill- python
# Enter Higher Education- BSCS
# Enter Year of Graduation- 2024
# ('ahmad', 'BSCS', 'python', '2024')

# %% [markdown]
# # Set

# %% [markdown]
# ###`Q1:` Write a program to find set of common elements in three lists using sets.
# ```
# Input : ar1 = [1, 5, 10, 20, 40, 80]
#         ar2 = [6, 7, 20, 80, 100]
#         ar3 = [3, 4, 15, 20, 30, 70, 80, 120]
#
# Output : [80, 20]
# ```

# %%
# write your code here
ar1 = [1, 5, 10, 20, 40, 80]
ar2 = [6, 7, 20, 80, 100]
ar3 = [3, 4, 15, 20, 30, 70, 80, 120]

set1 = set(ar1)
set2 = set(ar2)
set3 = set(ar3)

common = list(set1 & set2 & set3)
print(common)
# Out:
# [80, 20]

# %% [markdown]
# ###`Q2:` Write a program to count unique number of vowels using sets in a given string. Lowercase and upercase vowels will be taken as different.
#
# `Input:`
# ```
# Str1 = "hands-on data science mentorship progrAm with live classes at affordable fee only on CampusX"
# ```
# `Output:`
# ```
# No of unique vowels-6
# ```

# %%
# write your code here
Str1 = "hands-on data science mentorship progrAm with live classes at affordable fee only on CampusX"

str_set = set(Str1)
vowels = ['a','e','i','o','u', 'A', 'E', 'I', 'O', 'U']
count = 0
for i in range(len(str_set)):
  if str_set.pop() in vowels:
    count += 1
print("No of unique vowels-",count)
# Out:
# No of unique vowels- 5

# %% [markdown]
# ### `Q3:` Write a program to Check if a given string is binary string of or not.
#
# A string is said to be binary if it's consists of only two unique characters.
#
# Take string input from user.
#
# ```
# Input: str = "01010101010"
# Output: Yes
#
# Input: str = "1222211"
# Output: Yes
#
# Input: str = "Campusx"
# Output: No
# ```

# %%
# write your code here
str1 = input("Input: ")
set_str = set(str1)


print("Output: ", end="")
if len(set_str) == 2:
  print("Yes")
else:
  print("No")
# Out:
# Input: 121212122121121212121212121
# Output: Yes

# %% [markdown]
# ### `Q4`: find union of n arrays.
#
# **Example 1:**
#
# Input:
# ```bash
# [[1, 2, 2, 4, 3, 6],
#  [5, 1, 3, 4],
#  [9, 5, 7, 1],
#  [2, 4, 1, 3]]
# ```
#
# Output:
#
# ```bash
# [1, 2, 3, 4, 5, 6, 7, 9]
# ```

# %%
# write your code here
arr = [[1, 2, 2, 4, 3, 6],
 [5, 1, 3, 4],
 [9, 5, 7, 1],
 [2, 4, 1, 3]]



union = set(arr[0])
for i in range(1,len(arr)):
  union |= set(arr[i])

print(list(union))
# Out:
# [1, 2, 3, 4, 5, 6, 7, 9]

# %% [markdown]
# ### `Q5`: Intersection of two lists. Intersection of two list means we need to take all those elements which are common to both of the initial lists and store them into another list. Only use using **list-comprehension**.
#
# **Example 1:**
#
# Input:
# ```bash
# lst1 = {15, 9, 10, 56, 23, 78, 5, 4, 9}
# lst2 = {9, 4, 5, 36, 47, 26, 10, 45, 87}
# ```
#
# Output:
# ```bash
# [9, 10, 4, 5]
# ```
#
# **Example 2:**
#
# Input:
# ```bash
# lst1 = {4, 9, 1, 17, 11, 26, 28, 54, 69}
# lst2 = {9, 9, 74, 21, 45, 11, 63, 28, 26}
# ```
#
# Output:
# ```bash
# [9, 11, 26, 28]
# ```

# %%
# write your code here
# lst1 = {15, 9, 10, 56, 23, 78, 5, 4, 9}
# lst2 = {9, 4, 5, 36, 47, 26, 10, 45, 87}

lst1 = {4, 9, 1, 17, 11, 26, 28, 54, 69}
lst2 = {9, 9, 74, 21, 45, 11, 63, 28, 26}


intersection = {i for i in lst1 if i in lst2}
print(list(intersection))
# Out:
# [9, 26, 11, 28]

# %% [markdown]
# # Dictionary

# %% [markdown]
# ### `Q1`: Key with maximum unique values
#
# Given a dictionary with values list, extract key whose value has most unique values.
#
# **Example 1:**
#
# Input:
#
# ```bash
# test_dict = {"CampusX" : [5, 7, 9, 4, 0], "is" : [6, 7, 4, 3, 3], "Best" : [9, 9, 6, 5, 5]}
# ```
#
# Output:
# ```bash
# CampusX
# ```
#
# **Example 2:**
#
# Input:
# ```bash
# test_dict = {"CampusX" : [5, 7, 7, 7, 7], "is" : [6, 7, 7, 7], "Best" : [9, 9, 6, 5, 5]}
# ```
#
# Output:
# ```bash
# Best
# ```

# %%
# write your code here
test_dict = {"CampusX" : [5, 7, 9, 4, 0], "is" : [6, 7, 4, 3, 3], "Best" : [9, 9, 6, 5, 5]}

test_dict = {"CampusX" : [5, 7, 7, 7, 7], "is" : [6, 7, 7, 7], "Best" : [9, 9, 6, 5, 5]}

max = list(test_dict.keys())[0]
for i in test_dict:
  if len(set(test_dict[i])) > len(set(test_dict[max])):
    max = i

print(max)
# Out:
# Best

# %% [markdown]
# ### `Q2`: Replace words from Dictionary. Given String, replace it’s words from lookup dictionary.
#
# **Example 1:**
#
# Input:
#
# ```bash
# test_str = 'CampusX best for DS students.'
# repl_dict = {"best" : "is the best channel", "DS" : "Data-Science"}
# ```
#
# Output:
#
# ```bash
# CampusX is the best channel for Data-Science students.
# ```
#
# **Example 2:**
#
# Input:
# ```bash
# test_str = 'CampusX best for DS students.'
# repl_dict = {"good" : "is the best channel", "ds" : "Data-Science"}
# ```
#
# Output:
# ```bash
# CampusX best for DS students.
# ```

# %%
# write your code here
test_str = 'CampusX best for DS students.'
repl_dict = {"best" : "is the best channel", "DS" : "Data-Science"}

test_list = test_str.split()
for i in range(len(test_list)):
  if test_list[i] in repl_dict:
    test_list[i] = repl_dict[test_list[i]]

print(" ".join(test_list))
# Out:
# CampusX is the best channel for Data-Science students.

# %% [markdown]
# ### `Q3`: Convert List to List of dictionaries. Given list values and keys list, convert these values to key value pairs in form of list of dictionaries.
#
# **Example 1:**
#
# Input:
# ```bash
# test_list = ["DataScience", 3, "is", 8]
# key_list = ["name", "id"]
# ```
#
# Output:
#
# ```bash
# [{'name': 'DataScience', 'id': 3}, {'name': 'is', 'id': 8}]
# ```
#
# **Example 2:**
#
# Input:
# ```bash
# test_list = ["CampusX", 10]
# key_list = ["name", "id"]
# ```
#
# Output:
#
# ```bash
# [{'name': 'CampusX', 'id': 10}]
# ```

# %%
# write your code here
test_list = ["DataScience", 3, "is", 8]
key_list = ["name", "id"]

test_list = ["CampusX", 10]
key_list = ["name", "id"]


# output_dict = dict(zip(key_list,test_list))
# print([output_dict])

output = list()

for i in range(len(test_list)):
  add = dict()
  add[key_list[i%2]] = test_list[i]
  output.append(add)

output
# Out:
# [{'name': 'CampusX'}, {'id': 10}]

# %% [markdown]
# ### `Q4`: Convert a list of Tuples into Dictionary.
#
# **Example 1:**
#
# Input:
# ```bash
# [("akash", 10), ("gaurav", 12), ("anand", 14), ("suraj", 20), ("akhil", 25), ("ashish", 30)]
# ```
#
# Output:
# ```bash
# {'akash': [10], 'gaurav': [12], 'anand': [14], 'suraj': [20], 'akhil': [25], 'ashish': [30]}
# ```
#
# **Example 2:**
#
# Input:
# ```bash
# [('A', 1), ('B', 2), ('C', 3)]
# ```
#
# Output:
# ```bash
# {'A': [1], 'B': [2], 'C': [3]}
# ```

# %%
# write your code here
list1 = [("akash", 10), ("gaurav", 12), ("anand", 14), ("suraj", 20), ("akhil", 25), ("ashish", 30)]

list2 = [('A', 1), ('B', 2), ('C', 3)]

# dict1 = dict(list1)
# print(dict1)

# dict2 = dict(list2)
# print(dict2)


dict1 = {i:[j] for i,j in list1 }
dict2 = {i:[j] for i,j in list2 }

print(dict1)
print(dict2)
# Out:
# {'akash': [10], 'gaurav': [12], 'anand': [14], 'suraj': [20], 'akhil': [25], 'ashish': [30]}
# {'A': [1], 'B': [2], 'C': [3]}

# %% [markdown]
# ### `Q5`: Sort Dictionary key and values List.
#
# **Example 1:**
#
# Input:
#
# ```bash
# {'c': [3], 'b': [12, 10], 'a': [19, 4]}
# ```
#
# Output:
#
# ```bash
# {'a': [4, 19], 'b': [10, 12], 'c': [3]}
# ```
#
# **Example 2:**
#
# Input:
#
# ```bash
# {'c': [10, 34, 3]}
# ```
#
# Output:
#
# ```bash
# {'c': [3, 10, 34]}
# ```

# %%
# write your code here

dict1 = {'c': [3], 'b': [12, 10], 'a': [19, 4]}
dict2 = {'c': [10, 34, 3]}
for i in dict1:
  dict1[i] = sorted(dict1[i])


dict2 = {i: sorted(dict2[i]) for i in dict2}
print(dict2)

print(dict1)
# Out:
# {'c': [3, 10, 34]}
# {'c': [3], 'b': [10, 12], 'a': [4, 19]}
